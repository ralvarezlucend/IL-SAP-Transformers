# %%
from analysis.utils import (
    plot_combined_heads,
    plot_kl_divergence_simple,
    plot_val_loss_simple,
    fetch_run_data,
)

# %%
run_id = "p6mze2ux"
attention_steps = [0, 270, 580, 1500]
divergence_steps = [330, 580]
max_steps = 2000
figsize = (12, 8)

# %%
data = fetch_run_data(run_id, metrics=["val_loss"])
cfg = data["config"]
student_cfg = cfg["student"]

full_dissect_keys = [
    "dropout",
    "use_key_projection",
    "layer_normalization",
    "use_mlp",
    "teacher_readout",
    "use_output_projection",
    "skip_connection",
    "attention_disentanglement",
    "pe_type",
    "attention_bias",
]

for key in full_dissect_keys:
    print(f"{key}: {student_cfg[key]}")

# %%
plot_combined_heads(
    f"run-{run_id}-val_attention_weights",
    steps=attention_steps,
    split="val",
    save_name="attention-infinite-data",
)

# %%
plot_kl_divergence_simple(
    run_id=run_id,
    divergence_steps=divergence_steps,
    max_steps=max_steps,
    figsize=figsize,
    learnable=False,
    shift_steps=False,
    save_name="kl-infinite-data",
)

# %%
plot_val_loss_simple(
    run_id=run_id,
    divergence_steps=divergence_steps,
    max_steps=max_steps,
    figsize=figsize,
    shift_steps=False,
    save_name="val-loss-infinite-data",
)
