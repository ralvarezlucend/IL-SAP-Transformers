# %%
from analysis.utils import (
    plot_combined_heads,
    plot_kl_divergence_simple,
    plot_val_loss_simple,
    fetch_run_data,
)

# %%
run_id = "seo4z7uz"
data = fetch_run_data(run_id, metrics=["val_loss"])
cfg = data["config"]
student_cfg = cfg["student"]

full_dissect_keys = [
    "dropout",
    "use_key_projection",
    "layer_normalization",
    "use_mlp",
    "teacher_readout",
    "use_output_projection",
    "skip_connection",
    "attention_disentanglement",
    "pe_type",
]

for key in full_dissect_keys:
    print(f"{key}: {student_cfg[key]}")

# %%
attention_steps = [0, 70, 375, 1500]
divergence_steps = [2090, 2410]
max_steps = 3000
figsize = (12, 8)

# %%
plot_combined_heads(
    f"run-{run_id}-val_attention_weights",
    steps=attention_steps,
    split="val",
    save_name="attention-reversed",
)

# %%
plot_kl_divergence_simple(
    run_id=run_id,
    divergence_steps=divergence_steps,
    max_steps=max_steps,
    figsize=figsize,
    learnable=False,
    shift_steps=True,
    save_name="kl-reversed",
)

# %%
plot_val_loss_simple(
    run_id=run_id,
    divergence_steps=divergence_steps,
    max_steps=max_steps,
    figsize=figsize,
    shift_steps=True,
    save_name="val-loss-reversed",
)
