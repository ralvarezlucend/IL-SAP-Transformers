# %% [markdown]
# # Overlapping Spans

# %%
from figures.utils import plot_kl_divergence_simple, plot_separated_heads, plot_val_loss_simple

# %% [markdown]
# # 3 Heads

# %%
RUN_ID = "c9pd8yft"

# %%
plot_kl_divergence_simple(
    run_id=RUN_ID, 
    learnable=True, 
    divergence_steps=[2230, 3000]
)

# %%
plot_separated_heads(
    run_id=RUN_ID,
    steps=[100, 400, 1900],
    frequency=50,   
    split="val",
    # head_colors={0: "#2ca02c", 1: "#ff7f0e", 2: "#1f77b4"},
    # (row_idx, col_idx)
    staircases= { 
        (0, 0): [0, -4], (0, 1): [0, -4], (0, 2): [0, -4],
        (1, 0): [0, -4], (1, 1): [-2, -6], (1, 2): [0, -4],
        (2, 0): [0, -4], (2, 1): [-4, -8], (2, 2): [0, -6],
    },
    save_name="figures/overlapping-3heads"
)
# Out:
# Loading from cache: 67d5b29bda343931c3eca56335fcfd30.pkl
# Loading from cache: 67d5b29bda343931c3eca56335fcfd30.pkl
# Loading from cache: 172abfae6e68e6731f81d5e26ba2b20a.pkl
# Loading from cache: a21fd1f4c39f5e1e8127e7fad60fdb24.pkl
# Saved figure to figures/overlapping-3heads.pdf

# %% [markdown]
# # 4 Heads

# %%
RUN_ID = "d5w941d1"

# %%
plot_separated_heads(
    run_id=RUN_ID,
    steps=[100, 400, 1900],
    frequency=50,   
    split="val",
    head_colors={0: "#2ca02c", 1: "#ff7f0e", 2: "#1f77b4", 3: "#9467bd"},
    # (row_idx, col_idx)
    staircases= { 
        (0, 0): [0, -4], (0, 1): [0, -4], (0, 2): [0, -4], (0, 3): [0, -4],
        (1, 0): [-2, -6], (1, 1): [0, -4], (1, 2): [0, -4], (1, 3): [-2, -6],
        (2, 0): [-4, -8], (2, 1): [0, -4], (2, 2): [0, -4], (2, 3): [-2, -6],
    },
    save_name="figures/overlapping-4heads"
)
# Out:
# Loading from cache: 46a22e8d7bc85ae89d504109a40211e5.pkl
# Loading from cache: 46a22e8d7bc85ae89d504109a40211e5.pkl
# Loading from cache: 594188845703c22c16299ef74f745f64.pkl
# Loading from cache: 3e1368951ee24efcd9662d81fbac3bbf.pkl
# Saved figure to figures/overlapping-4heads.pdf

# %%
plot_kl_divergence_simple(
    run_id=RUN_ID, 
    learnable=True, 
    divergence_steps=[2150, 2700],
    shift_steps=2000,
    save_name="figures/kl_div_overlapping_4heads"
)
# Out:
# Saved figure to figures/kl_div_overlapping_4heads.pdf

# %%
plot_val_loss_simple(
    run_id=RUN_ID,
    divergence_steps=[2150, 2700],
    shift_steps=2000,
    save_name="figures/val_loss_overlapping_4heads"
)
# Out:
# Saved figure to figures/val_loss_overlapping_4heads.pdf

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
sns.palplot(colors)
plt.show()
print(colors)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
