# %% [markdown]
# # Non-Uniform Positions within Spans

# %%
from figures.utils import plot_kl_divergence_simple, plot_combined_heads
# Out:
# /Users/rodrigoalvarezlucendo/Projects/ar-classification/.venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
RUN_ID = "mgj8u2o3"

# %%
plot_kl_divergence_simple(
    run_id=RUN_ID, 
    learnable=True, 
    divergence_steps=[2130, 2280],
    max_steps=3000,
    shift_steps=2000,
    save_name="figures/kl_div_non_uniform_learnable"
)
# Out:
# Saved figure to figures/kl_div_non_uniform_learnable.pdf

# %%
plot_combined_heads(
    run_id=RUN_ID,
    steps=[0, 100, 200, 1000],
    frequency=50,   
    split="val",
    head_colors={0: "#2ca02c", 1: "#ff7f0e", 2: "#1f77b4"},
    staircases={1: [0, -2], 2: [0, -2, -4], 3: [0, -2, -4, -6]},
    save_name="figures/attention_heads_non_uniform.pdf"
)
# Out:
# Loading from cache: a35b0590e82de629cbe586829fd39f18.pkl
# Loading from cache: 94b4bb398cbe6c85535eb9f298c41796.pkl
# Loading from cache: 2ae2aea1dba1704c8cee4219d9c5b2f3.pkl
# Loading from cache: 6eea6ef77173078a76b847a01d928221.pkl
# Saved figure to figures/attention_heads_non_uniform.pdf.pdf
