# %% [markdown]
# # SGD Full Transformer with 1 Layer

# %%
from figures.utils import plot_kl_divergence_simple, plot_combined_heads
# Out:
# /Users/rodrigoalvarezlucendo/Projects/ar-classification/.venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
RUN_ID = "m0qjhj8n"

# %%
plot_kl_divergence_simple(
    run_id=RUN_ID, 
    learnable=True, 
    divergence_steps=[10600, 14000],
    max_steps=17000,
    shift_steps=10000,
    save_name="figures/kl_div_sgd_full_one_layer"
)
# Out:
# Saved figure to figures/kl_div_sgd_full_one_layer.pdf

# %%
plot_combined_heads(
    run_id=RUN_ID,
    steps=[0, 600, 3800, 6600],
    frequency=200,   
    split="val",
    head_colors={0: "#2ca02c", 2: "#ff7f0e", 1: "#1f77b4"},
    staircases={1: [0, -4], 2: [0, -4, -8], 3: [0, -4, -8, -12]},
    save_name="figures/attention_sgd_full_one_layer.pdf"
)
# Out:
# Loading from cache: c5ea33827a64e135b0c5c214aedac16b.pkl
# Loading from cache: f750051cd7e08ba44ba5cddba5d35dc4.pkl
# Loading from cache: 98d8aa71034ecdbf26c65dba7181c776.pkl
# Loading from cache: 5120e1a2b83dccf8df9920e6221ae135.pkl
# Saved figure to figures/attention_sgd_full_one_layer.pdf.pdf
